# %%
#question1
import numpy as np
arr=np.random.rand(10,1)
print(np.mean(arr))
# Out:
# 0.5996077978495573

# %%
#question 2
import numpy as np
arr=np.random.rand(20,1)
print(np.var(arr))
print(np.std(arr))
# Out:
# 0.08462667787554858
# 0.29090664804288774

# %%
#question 3
import numpy as np
arr=np.random.rand(20,25)
arr1=np.random.rand(10,20)
arr2=np.matmul(arr1,arr)
print(arr2)
print(np.sum(arr2))
# Out:
# [[5.03736089 3.54141139 4.85247405 5.22983835 5.01369512 4.73296094
#   4.33999871 5.53859456 5.72669307 5.90445716 4.87373025 5.62858046
#   4.70632663 4.41073281 4.03188484 5.42350568 5.26541369 6.13743917
#   5.61677056 3.35331594 5.64241768 4.86404249 4.77923161 5.61279737
#   4.90952832]
#  [5.69655838 4.52389463 5.10768316 5.37347887 4.72972981 5.02290482
#   4.14020432 6.22581585 5.04548338 5.75720072 6.33927055 6.72201047
#   5.10447463 3.63270142 4.17202545 4.9694561  5.68140834 5.75096042
#   5.95795493 3.39863179 4.37313336 5.28795644 4.39724312 4.94392228
#   4.56677411]
#  [5.45558926 4.07300603 5.06345295 5.70632502 4.92037176 5.16732367
#   4.87730732 5.67519955 5.45043002 6.09276457 6.32290012 6.76737051
#   5.60726778 4.82831848 5.00027705 4.89204538 5.69046328 6.09909188
#   6.17320718 3.46193129 4.76813895 5.1931899  4.75256593 5.13499138
#   4.90775025]
#  [6.61908356 5.6991999  6.1781973  7.21807714 6.68013152 6.78997916
# ...

# %%
#question 4
import numpy as np
arr=np.arange(10).reshape(10,1)

def f(x):
    return(1/(1+np.exp(-x)))

n=f(arr)
print(n)
# Out:
# [[0.5       ]
#  [0.73105858]
#  [0.88079708]
#  [0.95257413]
#  [0.98201379]
#  [0.99330715]
#  [0.99752738]
#  [0.99908895]
#  [0.99966465]
#  [0.99987661]]
